# %%
from dataloader import NetCDFSR, xr_standardize_field
import xarray as xr
import numpy as np
import glob
import torch
from prep_gan import find_nearest_index, to_utc

from distributed import Client
from sklearn.metrics import mean_squared_error

from sklearn.decomposition import PCA
from scipy.interpolate import NearestNDInterpolator

import matplotlib.pyplot as plt
from models.generator import Generator
from models.critic import Critic

# %load_ext autoreload
# %autoreload 2

torch.cuda.empty_cache()
import dask
dask.config.set({"array.slicing.split_large_chunks": True})

# %%
# stri = ""
# for var in list(xr.open_dataset(constants).data_vars)[:-1]:
#     stri+=var+","
# stri

# %%
constants = "data/regrid_16_mask_wrfout_conus_constants_era_to_regrid.nc"
fine_mask = xr.open_dataset(constants)
plt.imshow(xr.open_dataset(constants).LANDMASK.values[0, ...], origin="lower")

# %%
fine_mask
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 540, lon: 1100, time: 1)
# Coordinates:
#   * time      (time) float64 0.0
#   * lon       (lon) float32 -139.1 -139.0 -138.9 -138.8 ... -56.78 -56.71 -56.63
#   * lat       (lat) float32 18.14 18.21 18.29 18.36 ... 58.34 58.41 58.49 58.56
# Data variables:
#     LANDMASK  (time, lat, lon) float32 ...
# Attributes: (12/111)
#     CDI:                             Climate Data Interface version ?? (http:...
#     Conventions:                     CF-1.6
#     history:                         Thu May 27 13:11:42 2021: cdo remapnn,ta...
#     TITLE:                            OUTPUT FROM WRF V3.4.1 MODEL
#     START_DATE:                      2001-02-28_00:00:00
#     SIMULATION_START_DATE:           2000-10-01_00:00:00
#     ...                              ...
#     ISLAKE:                          -1
#     ISICE:                           15
#     ISURBAN:                         13
#     ISOILWATER:                      14
#     NCO:                             4.7.2
#     CDO:                             Climate Data Operators version 1.9.3 (ht...

# %%
coarse_constants = "data/_grib2netcdf-webmars-public-svc-blue-005-6fe5cac1a363ec1525f54343b6cc9fd8-J3TMVF.nc"
coarse_mask = xr.open_dataset(coarse_constants)
coarse_mask = coarse_mask.sortby('latitude', ascending=True)
mlat1 = np.argmin(np.abs(fine_mask.lat.min()-coarse_mask.latitude).values)
mlat2 = np.argmin(np.abs(fine_mask.lat.max()-coarse_mask.latitude).values)
mlon1 = np.argmin(np.abs(fine_mask.lon.min()-(-360+coarse_mask.longitude)).values)
mlon2 = np.argmin(np.abs(fine_mask.lon.max()-(-360+coarse_mask.longitude)).values)
coarse_mask = coarse_mask.lsm[0, mlat1:mlat2, mlon1:mlon2]

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
# Depending on your workstation specifications, you may need to adjust these values.
# On a single machine, n_workers=1 is usually better.
client=Client(n_workers=8, threads_per_worker=2, memory_limit="1.5GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:34405' processes=8 threads=16, memory=11.18 GiB>

# %% [markdown]
# Load data and extract synchronous time stamps

# %%
hr_dataroot_U10 = "data/wrf/U10_regrid_16/regrid_16_6hrly_wrf2d_d01_ctrl_U10*.nc"
hr_dataroot_V10 = "data/wrf/V10_regrid_16/regrid_16_6hrly_wrf2d_d01_ctrl_V10*.nc"

fine_u = xr.open_mfdataset(glob.glob(hr_dataroot_U10), combine='by_coords', engine='netcdf4', concat_dim='Time', chunks={"Times":10})
fine_v = xr.open_mfdataset(glob.glob(hr_dataroot_V10), combine='by_coords', engine='netcdf4', concat_dim='Time', chunks={"Times":10})

# %%
dataroot = "./data/interim_2000-10-01_to_2013-09-30.nc"

target = '10UV_GDS4_SFC'
coarse = xr.open_dataset(dataroot).astype("float")
coarse = coarse.sortby('latitude', ascending=True)
coarse_u10 = coarse.u10.loc["2000-01-01":"2015-05-30"].chunk({"time": 10})
coarse_v10 = coarse.v10.loc["2000-01-01":"2015-05-30"].chunk({"time": 10})

# scale factor
sf = 8

# %%
coarse_u10.time.min(), coarse_u10.time.max()
# Out:
# (<xarray.DataArray 'time' ()>
#  array('2000-10-01T00:00:00.000000000', dtype='datetime64[ns]'),
#  <xarray.DataArray 'time' ()>
#  array('2013-09-30T18:00:00.000000000', dtype='datetime64[ns]'))

# %% [markdown]
# Mark starting long and lat boundaries

# %%
coarse_u10.longitude.min(), coarse_u10.latitude.min()
# Out:
# (<xarray.DataArray 'longitude' ()>
#  array(-139.055, dtype=float32),
#  <xarray.DataArray 'latitude' ()>
#  array(18.137, dtype=float32))

# %% [markdown]
# Fine the regular grid size

# %%
np.diff(coarse_u10.longitude).mean()/sf, np.diff(coarse_u10.latitude).mean()/sf
# Out:
# (0.09375114738941193, 0.09375)

# %% [markdown]
# Number of steps

# %%
coarse_u10.longitude.shape[0]*sf, coarse_u10.latitude.shape[0]*sf
# Out:
# (880, 432)

# %%
tidx = 15000
vmin, vmax = -13, 6
low, up, l, r = 4, 20, 70, 86
fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(fine_u.U10[tidx, sf*low:sf*up, sf*l:sf*r], origin="lower",)# vmin=vmin, vmax=vmax)
ax[1].imshow(coarse_u10[tidx, low:up, l:r], origin="lower", )#vmin=vmin, vmax=vmax)
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(fine_v.V10[tidx, sf*low:sf*up, sf*l:sf*r], origin="lower",)# vmin=vmin, vmax=vmax)
ax[1].imshow(coarse_v10[tidx, low:up, l:r], origin="lower", )#vmin=vmin, vmax=vmax)

# %%
import datetime as datetime
Times_dt = []
for t in fine_u.Times:
    year = int(str(float(t))[:4])
    month = int(str(float(t))[4:6])
    day = int(str(float(t))[6:8])
    hours = int(np.round(24*float(str(float(t))[8:])))
    Times_dt.append(np.datetime64(datetime.datetime(year, month, day, hours)))
Times_dt = np.array(Times_dt).astype('datetime64[D]')

# %%
coarse_u10.time.values.astype(np.datetime64), Times_dt
# Out:
# (array(['2000-10-01T00:00:00.000000000', '2000-10-01T06:00:00.000000000',
#         '2000-10-01T12:00:00.000000000', ...,
#         '2013-09-30T06:00:00.000000000', '2013-09-30T12:00:00.000000000',
#         '2013-09-30T18:00:00.000000000'], dtype='datetime64[ns]'),
#  array(['2000-10-01', '2000-10-01', '2000-10-01', ..., '2013-09-30',
#         '2013-09-30', '2013-09-30'], dtype='datetime64[D]'))

# %%
to_utc(coarse_u10.time.values.astype('datetime64[D]')), to_utc(Times_dt)
# Out:
# (array([9.7035840e+08, 9.7035840e+08, 9.7035840e+08, ..., 1.3804992e+09,
#         1.3804992e+09, 1.3804992e+09]),
#  array([9.7035840e+08, 9.7035840e+08, 9.7035840e+08, ..., 1.3804992e+09,
#         1.3804992e+09, 1.3804992e+09]))

# %%
coarse_mask.values.shape
# Out:
# (54, 109)

# %%
u10 = fine_u.U10[1:18000, sf*low:sf*up, sf*l:sf*r]
v10 = fine_v.V10[1:18000, sf*low:sf*up, sf*l:sf*r]
fmask = np.repeat(fine_mask.LANDMASK.values[0, sf*low:sf*up, sf*l:sf*r][np.newaxis, :, :], u10.shape[0], axis=0)

coarse_u10_patch = coarse_u10[1:18000, low:up, l:r]
coarse_v10_patch = coarse_v10[1:18000, low:up, l:r]
cmask = np.repeat(coarse_mask.values[low:up, l:r][np.newaxis, :, :], u10.shape[0], axis=0)

u10 = xr_standardize_field(u10)
v10 = xr_standardize_field(v10)
coarse_u10_patch =  xr_standardize_field(coarse_u10_patch)
coarse_v10_patch =  xr_standardize_field(coarse_v10_patch)

print(u10.shape)
# Out:
# (17999, 128, 128)

# %%
# assert np.isclose(float(u10.mean().compute()), 0.0, atol=10-5)
# assert np.isclose(float(v10.mean().compute()), 0.0, atol=10-5)

# assert np.isclose(float(coarse_u10_patch.mean().compute()), 0.0, atol=10-5)
# assert np.isclose(float(coarse_v10_patch.mean().compute()), 0.0, atol=10-5)

# assert np.isclose(float(u10.std().compute()), 1.0, atol=10-5)
# assert np.isclose(float(v10.std().compute()), 1.0, atol=10-5)

# assert np.isclose(float(coarse_u10_patch.std().compute()), 1.0, atol=10-5)
# assert np.isclose(float(coarse_v10_patch.std().compute()), 1.0, atol=10-5)

# %%
coarse_mask.shape, coarse_u10_patch.shape
# Out:
# ((54, 109), (17999, 16, 16))

# %%
coarse = np.stack([coarse_u10_patch, coarse_v10_patch, cmask], axis=1)
fine = np.stack([u10, v10, fmask], axis=1)

del coarse_u10_patch
del coarse_v10_patch
del cmask
del fmask
# coarse = xr.concat([coarse_u10_patch, coarse_v10_patch], dim="var").transpose('time', 'var', 'latitude', 'longitude')
# fine = xr.concat([u10, v10], dim="var").transpose('Times', 'var', 'lat', 'lon')

# %%
coarse.shape, fine.shape
# Out:
# ((17999, 3, 16, 16), (17999, 3, 128, 128))

# %%
# PCA
ncomp = 25
fine_pca_u10 = np.array(fine[:, 0, ...]).reshape(u10.shape[0], u10.shape[1]*u10.shape[2])
pca = PCA(n_components=ncomp)
pca.fit(fine_pca_u10)
fine_sp_basis_u10 = pca.components_.reshape(ncomp, u10.shape[1]*u10.shape[2])/pca.explained_variance_[:, np.newaxis]
del fine_pca_u10
# fine_sp_basis_u10 = np.divide(fine_sp_basis_u10, pca.explained_variance_)

fine_pca_v10 = np.array(fine[:, 1, ...]).reshape(v10.shape[0], v10.shape[1]*v10.shape[2])
pca = PCA(n_components=ncomp)
pca.fit(fine_pca_v10)
del fine_pca_v10

fine_sp_basis_v10 = pca.components_.reshape(ncomp, v10.shape[1]*v10.shape[2])/pca.explained_variance_[:, np.newaxis]
fine_sp_basis = np.stack([fine_sp_basis_u10, fine_sp_basis_v10], axis=1)
del fine_sp_basis_v10
del fine_sp_basis_u10

print(fine_sp_basis.shape)
# Out:
# (25, 2, 16384)

# %%
fine_t = torch.from_numpy(np.array(fine)).float()
coarse_t = torch.from_numpy(np.array(coarse)).float()
pcas_t = torch.from_numpy(fine_sp_basis).float()
pcas_t.size(), coarse_t.size(), pcas_t.dtype, coarse_t.dtype
# Out:
# (torch.Size([25, 2, 16384]),
#  torch.Size([17999, 3, 16, 16]),
#  torch.float32,
#  torch.float32)

# %%
del u10
del v10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9a7d9c8e3a37> in <module>
#       1 del u10
#       2 del v10
# ----> 3 del coarse_u10_patch
#       4 del coarse_v10_patch
#
# NameError: name 'coarse_u10_patch' is not defined

# %%
# del fine_pca_u10
# del fine_pca_v10
del fine_sp_basis

# %%
del coarse
del fine

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
batch_size = 64
dataset = NetCDFSR(
    fine_t,
    coarse_t,
    pcas_t,
    device=device
)

dataloader = torch.utils.data.DataLoader(
    dataset=dataset,
    batch_size=batch_size,
    shuffle=True
)

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
real_batch, real_cbatch, pcas = next(iter(dataloader))
fixed = {"coarse": real_cbatch[:2, ...], "fine": real_batch[:2, ...]}
pcas.size()
pcas.shape, fixed["coarse"].shape, fixed["fine"].shape,
# Out:
# (torch.Size([64, 1, 25, 2, 16384]),
#  torch.Size([2, 3, 16, 16]),
#  torch.Size([2, 3, 128, 128]))

# %%
# from models import Generator, Discriminator
# discriminator_test = Discriminator(15, 120, 2)
# generator_test = Generator(15, 120, 2)
# gt = generator_test(fixed["coarse"])
# print(gt.shape)

# discriminator_test(fixed["fine"]).shape,
# generator_test(fixed["coarse"]).shape,
# discriminator_test(gt)

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
# from models import Generator, Discriminator#, patch_discriminator

# discriminator = patch_discriminator().to(device)#Discriminator(7, 14, 1).to(device)
critic = Critic(16, 128, 3).to(device)
generator = Generator(16, 128, 3).to(device)
lr = 0.00025

# %%
pcas_t.size()
# Out:
# torch.Size([25, 2, 16384])

# %%
G_optimizer = torch.optim.Adam(generator.parameters(), lr=lr, betas=(.9, .99))
C_optimizer = torch.optim.Adam(critic.parameters(), lr=lr, betas=(.9, .99))

# Set up trainer
from training import Trainer
epochs = 500
models = {"generator": generator, "critic": critic, "gen_optimizer": G_optimizer, "critic_optimizer": C_optimizer}
hyper_params = {
    "gp_weight": 10,
    "critic_iterations": 5,
    "batch_size": batch_size,
    "gamma": 0.01,
    "eof_weight": (1-0.01)/4,
    "div_weight": (1-0.01)/4,
    "vort_weight": (1-0.01)/4,
    "content_weight": (1-0.01)/4,
}

run_params = {
    "epochs": epochs,
    "print_every": 500,
    "save_every": 250,
    "use_cuda": True,
    "device": device,
    "log_path": "mlruns"
}


# trainer = Trainer(generator, discriminator, G_optimizer, D_optimizer,
#                   use_cuda=torch.cuda.is_available(), print_every=500, save_every=500, device=device)
experiment = "WGAN-GP Extended Loss Equal Weights"
tags = {"description": "equal weights on loss"}

from mlflow.tracking import MlflowClient
client = MlflowClient()
# print(dir(client))
print(client.get_experiment_by_name(experiment).experiment_id)


trainer = Trainer(models, hyper_params, run_params, experiment, tags)

# Train model for N epochs
trainer.train(
    dataloader,
    epochs=epochs,
    fixed=fixed,
)
torch.cuda.empty_cache()
# Out:
# INFO:root:
# Epoch 0
# 1
# INFO:root:Gradient Penalty: 523.0858154296875
# INFO:root:Wasserstein Distance Estimate: 1166.60986328125
# INFO:root:System Free Memory: 480.0
# INFO:root:Iteration number: 250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.888074278831482
# INFO:root:Divergence L2: 2.003021478652954
# INFO:root:Vorticity L2: 2.000440835952759
# INFO:root:Content L2: 0.6318665742874146
# INFO:root:Generator loss: 1.2750272750854492
# INFO:root:
# Epoch 1
# INFO:root:Gradient Penalty: 319.2750244140625
# INFO:root:Wasserstein Distance Estimate: 799.5914916992188
# INFO:root:System Free Memory: 404.0
# INFO:root:Iteration number: 500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 2.0836987495422363
# INFO:root:Divergence L2: 2.0104095935821533
# INFO:root:Vorticity L2: 2.0054028034210205
# INFO:root:Content L2: 0.7093071937561035
# INFO:root:Generator loss: -0.4814574718475342
# INFO:root:
# Epoch 2
# INFO:root:Gradient Penalty: 350.627685546875
# INFO:root:Wasserstein Distance Estimate: 831.928466796875
# INFO:root:System Free Memory: 389.0
# INFO:root:Iteration number: 750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 2.0412046909332275
# INFO:root:Divergence L2: 2.0065627098083496
# INFO:root:Vorticity L2: 2.009974956512451
# INFO:root:Content L2: 0.7730317115783691
# INFO:root:Generator loss: 0.5571774244308472
# INFO:root:
# Epoch 3
# INFO:root:Gradient Penalty: 181.7005157470703
# INFO:root:Wasserstein Distance Estimate: 430.3173522949219
# INFO:root:System Free Memory: 402.0
# INFO:root:Iteration number: 1000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9915862083435059
# INFO:root:Divergence L2: 1.9938377141952515
# INFO:root:Vorticity L2: 1.9940215349197388
# INFO:root:Content L2: 0.5572899580001831
# INFO:root:Generator loss: 0.07658040523529053
# INFO:root:
# Epoch 4
# INFO:root:Gradient Penalty: 122.51964569091797
# INFO:root:Wasserstein Distance Estimate: 341.4884338378906
# INFO:root:System Free Memory: 373.0
# INFO:root:Iteration number: 1250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 2.053227186203003
# INFO:root:Divergence L2: 2.0086257457733154
# INFO:root:Vorticity L2: 2.002549886703491
# INFO:root:Content L2: 0.7329346537590027
# INFO:root:Generator loss: 1.5042572021484375
# INFO:root:
# Epoch 5
# INFO:root:Gradient Penalty: 126.18912506103516
# INFO:root:Wasserstein Distance Estimate: 326.2791748046875
# INFO:root:System Free Memory: 394.0
# INFO:root:Iteration number: 1500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 2.013075828552246
# INFO:root:Divergence L2: 2.000082492828369
# INFO:root:Vorticity L2: 1.997503399848938
# INFO:root:Content L2: 0.7072445750236511
# INFO:root:Generator loss: 1.127126932144165
# INFO:root:
# Epoch 6
# INFO:root:Gradient Penalty: 95.49907684326172
# INFO:root:Wasserstein Distance Estimate: 288.58428955078125
# INFO:root:System Free Memory: 403.0
# INFO:root:Iteration number: 1750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9667837619781494
# INFO:root:Divergence L2: 2.0009865760803223
# INFO:root:Vorticity L2: 1.9948254823684692
# INFO:root:Content L2: 0.7298804521560669
# INFO:root:Generator loss: 0.4930126667022705
# INFO:root:
# Epoch 7
# INFO:root:Gradient Penalty: 105.09378051757812
# INFO:root:Wasserstein Distance Estimate: 251.0937042236328
# INFO:root:System Free Memory: 428.0
# INFO:root:Iteration number: 2000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.956722378730774
# INFO:root:Divergence L2: 1.993457555770874
# INFO:root:Vorticity L2: 1.9893250465393066
# INFO:root:Content L2: 0.7367286682128906
# INFO:root:Generator loss: 0.31829142570495605
# INFO:root:Gradient Penalty: 75.1585693359375
# INFO:root:Wasserstein Distance Estimate: 199.18511962890625
# INFO:root:System Free Memory: 433.0
# INFO:root:Iteration number: 2250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9260517358779907
# INFO:root:Divergence L2: 1.985654354095459
# INFO:root:Vorticity L2: 1.9813967943191528
# INFO:root:Content L2: 0.6702508330345154
# INFO:root:Generator loss: -0.7522636651992798
# INFO:root:
# Epoch 8
# INFO:root:Gradient Penalty: 52.69585037231445
# INFO:root:Wasserstein Distance Estimate: 170.166748046875
# INFO:root:System Free Memory: 414.0
# INFO:root:Iteration number: 2500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9296642541885376
# INFO:root:Divergence L2: 1.9926478862762451
# INFO:root:Vorticity L2: 1.9918116331100464
# INFO:root:Content L2: 0.7232789993286133
# INFO:root:Generator loss: 0.8871718645095825
# INFO:root:
# Epoch 9
# INFO:root:Gradient Penalty: 61.66075897216797
# INFO:root:Wasserstein Distance Estimate: 190.01107788085938
# INFO:root:System Free Memory: 369.0
# INFO:root:Iteration number: 2750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9026070833206177
# INFO:root:Divergence L2: 1.9908134937286377
# INFO:root:Vorticity L2: 1.9834001064300537
# INFO:root:Content L2: 0.7291545867919922
# INFO:root:Generator loss: 1.2971413135528564
# INFO:root:
# Epoch 10
# INFO:root:Gradient Penalty: 54.46308898925781
# INFO:root:Wasserstein Distance Estimate: 137.09793090820312
# INFO:root:System Free Memory: 382.0
# INFO:root:Iteration number: 3000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 2.0000803470611572
# INFO:root:Divergence L2: 1.9970217943191528
# INFO:root:Vorticity L2: 1.9965248107910156
# INFO:root:Content L2: 0.7827612161636353
# INFO:root:Generator loss: -0.21219396591186523
# INFO:root:
# Epoch 11
# INFO:root:Gradient Penalty: 57.524330139160156
# INFO:root:Wasserstein Distance Estimate: 157.91842651367188
# INFO:root:System Free Memory: 405.0
# INFO:root:Iteration number: 3250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9275552034378052
# INFO:root:Divergence L2: 1.9835350513458252
# INFO:root:Vorticity L2: 1.984480857849121
# INFO:root:Content L2: 0.7659987807273865
# INFO:root:Generator loss: 0.06497681140899658
# INFO:root:
# Epoch 12
# INFO:root:Gradient Penalty: 60.65940856933594
# INFO:root:Wasserstein Distance Estimate: 130.88026428222656
# INFO:root:System Free Memory: 390.0
# INFO:root:Iteration number: 3500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8684591054916382
# INFO:root:Divergence L2: 1.9831610918045044
# INFO:root:Vorticity L2: 1.9813613891601562
# INFO:root:Content L2: 0.7221059799194336
# INFO:root:Generator loss: 2.4225659370422363
# INFO:root:
# Epoch 13
# INFO:root:Gradient Penalty: 47.113399505615234
# INFO:root:Wasserstein Distance Estimate: 142.87667846679688
# INFO:root:System Free Memory: 372.0
# INFO:root:Iteration number: 3750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9321606159210205
# INFO:root:Divergence L2: 1.9819053411483765
# INFO:root:Vorticity L2: 1.981986403465271
# INFO:root:Content L2: 0.7864620089530945
# INFO:root:Generator loss: 1.3610024452209473
# INFO:root:
# Epoch 14
# INFO:root:Gradient Penalty: 53.6436767578125
# INFO:root:Wasserstein Distance Estimate: 160.59005737304688
# INFO:root:System Free Memory: 411.0
# INFO:root:Iteration number: 4000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7793837785720825
# INFO:root:Divergence L2: 1.9853551387786865
# INFO:root:Vorticity L2: 1.9828464984893799
# INFO:root:Content L2: 0.6825220584869385
# INFO:root:Generator loss: -1.3012866973876953
# INFO:root:
# Epoch 15
# INFO:root:Gradient Penalty: 32.48711395263672
# INFO:root:Wasserstein Distance Estimate: 124.54446411132812
# INFO:root:System Free Memory: 407.0
# INFO:root:Iteration number: 4250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9104440212249756
# INFO:root:Divergence L2: 1.9875669479370117
# INFO:root:Vorticity L2: 1.98748779296875
# INFO:root:Content L2: 0.7506698966026306
# INFO:root:Generator loss: -0.5141642093658447
# INFO:root:Gradient Penalty: 41.06781768798828
# INFO:root:Wasserstein Distance Estimate: 128.79055786132812
# INFO:root:System Free Memory: 374.0
# INFO:root:Iteration number: 4500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.931779146194458
# INFO:root:Divergence L2: 1.9868971109390259
# INFO:root:Vorticity L2: 1.9786964654922485
# INFO:root:Content L2: 0.6584585905075073
# INFO:root:Generator loss: -1.0590928792953491
# INFO:root:
# Epoch 16
# INFO:root:Gradient Penalty: 80.48011779785156
# INFO:root:Wasserstein Distance Estimate: 194.7569580078125
# INFO:root:System Free Memory: 345.0
# INFO:root:Iteration number: 4750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8068270683288574
# INFO:root:Divergence L2: 1.9755642414093018
# INFO:root:Vorticity L2: 1.9818557500839233
# INFO:root:Content L2: 0.7144595980644226
# INFO:root:Generator loss: -0.5474960803985596
# INFO:root:
# Epoch 17
# INFO:root:Gradient Penalty: 22.049327850341797
# INFO:root:Wasserstein Distance Estimate: 100.51080322265625
# INFO:root:System Free Memory: 354.0
# INFO:root:Iteration number: 5000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8591930866241455
# INFO:root:Divergence L2: 1.9924575090408325
# INFO:root:Vorticity L2: 1.9997919797897339
# INFO:root:Content L2: 0.8012654185295105
# INFO:root:Generator loss: -0.24935269355773926
# INFO:root:
# Epoch 18
# INFO:root:Gradient Penalty: 43.45834732055664
# INFO:root:Wasserstein Distance Estimate: 186.67596435546875
# INFO:root:System Free Memory: 437.0
# INFO:root:Iteration number: 5250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7698404788970947
# INFO:root:Divergence L2: 1.9655896425247192
# INFO:root:Vorticity L2: 1.959395408630371
# INFO:root:Content L2: 0.6924396753311157
# INFO:root:Generator loss: -0.5216693878173828
# INFO:root:
# Epoch 19
# INFO:root:Gradient Penalty: 31.08289337158203
# INFO:root:Wasserstein Distance Estimate: 113.421142578125
# INFO:root:System Free Memory: 414.0
# INFO:root:Iteration number: 5500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7356058359146118
# INFO:root:Divergence L2: 1.9780147075653076
# INFO:root:Vorticity L2: 1.9781993627548218
# INFO:root:Content L2: 0.6665873527526855
# INFO:root:Generator loss: -0.7251526117324829
# INFO:root:
# Epoch 20
# INFO:root:Gradient Penalty: 44.005897521972656
# INFO:root:Wasserstein Distance Estimate: 129.36578369140625
# INFO:root:System Free Memory: 418.0
# INFO:root:Iteration number: 5750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8889150619506836
# INFO:root:Divergence L2: 1.973236322402954
# INFO:root:Vorticity L2: 1.9769474267959595
# INFO:root:Content L2: 0.7027844190597534
# INFO:root:Generator loss: -2.7679693698883057
# INFO:root:
# Epoch 21
# INFO:root:Gradient Penalty: 40.889644622802734
# INFO:root:Wasserstein Distance Estimate: 121.70057678222656
# INFO:root:System Free Memory: 439.0
# INFO:root:Iteration number: 6000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7324681282043457
# INFO:root:Divergence L2: 1.9662816524505615
# INFO:root:Vorticity L2: 1.9630018472671509
# INFO:root:Content L2: 0.6620868444442749
# INFO:root:Generator loss: 1.0188544988632202
# INFO:root:
# Epoch 22
# INFO:root:Gradient Penalty: 35.76051712036133
# INFO:root:Wasserstein Distance Estimate: 101.3826904296875
# INFO:root:System Free Memory: 391.0
# INFO:root:Iteration number: 6250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7761071920394897
# INFO:root:Divergence L2: 1.9507983922958374
# INFO:root:Vorticity L2: 1.9492312669754028
# INFO:root:Content L2: 0.5963205099105835
# INFO:root:Generator loss: -1.5056252479553223
# INFO:root:
# Epoch 23
# INFO:root:Gradient Penalty: 50.402950286865234
# INFO:root:Wasserstein Distance Estimate: 117.7772216796875
# INFO:root:System Free Memory: 401.0
# INFO:root:Iteration number: 6500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7277990579605103
# INFO:root:Divergence L2: 1.9747945070266724
# INFO:root:Vorticity L2: 1.976776361465454
# INFO:root:Content L2: 0.6820783019065857
# INFO:root:Generator loss: -0.44666731357574463
# INFO:root:Gradient Penalty: 36.91135025024414
# INFO:root:Wasserstein Distance Estimate: 71.98681640625
# INFO:root:System Free Memory: 415.0
# INFO:root:Iteration number: 6750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8148716688156128
# INFO:root:Divergence L2: 1.9608197212219238
# INFO:root:Vorticity L2: 1.9640990495681763
# INFO:root:Content L2: 0.6336624622344971
# INFO:root:Generator loss: -0.8181842565536499
# INFO:root:
# Epoch 24
# INFO:root:Gradient Penalty: 32.97035598754883
# INFO:root:Wasserstein Distance Estimate: 92.04713439941406
# INFO:root:System Free Memory: 420.0
# INFO:root:Iteration number: 7000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.9122570753097534
# INFO:root:Divergence L2: 1.9808402061462402
# INFO:root:Vorticity L2: 1.9784342050552368
# INFO:root:Content L2: 0.6577997803688049
# INFO:root:Generator loss: 1.2930314540863037
# INFO:root:
# Epoch 25
# INFO:root:Gradient Penalty: 28.72644805908203
# INFO:root:Wasserstein Distance Estimate: 41.525634765625
# INFO:root:System Free Memory: 400.0
# INFO:root:Iteration number: 7250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6143990755081177
# INFO:root:Divergence L2: 1.9696491956710815
# INFO:root:Vorticity L2: 1.9691585302352905
# INFO:root:Content L2: 0.6403969526290894
# INFO:root:Generator loss: 0.06497597694396973
# INFO:root:
# Epoch 26
# INFO:root:Gradient Penalty: 37.6341552734375
# INFO:root:Wasserstein Distance Estimate: 98.86721801757812
# INFO:root:System Free Memory: 409.0
# INFO:root:Iteration number: 7500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8753407001495361
# INFO:root:Divergence L2: 1.97836172580719
# INFO:root:Vorticity L2: 1.982352614402771
# INFO:root:Content L2: 0.7163486480712891
# INFO:root:Generator loss: 1.1304653882980347
# INFO:root:
# Epoch 27
# INFO:root:Gradient Penalty: 50.32295227050781
# INFO:root:Wasserstein Distance Estimate: 178.02786254882812
# INFO:root:System Free Memory: 414.0
# INFO:root:Iteration number: 7750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7563836574554443
# INFO:root:Divergence L2: 1.9641432762145996
# INFO:root:Vorticity L2: 1.9710477590560913
# INFO:root:Content L2: 0.6781973838806152
# INFO:root:Generator loss: 1.3427760601043701
# INFO:root:
# Epoch 28
# INFO:root:Gradient Penalty: 26.048538208007812
# INFO:root:Wasserstein Distance Estimate: 87.79241943359375
# INFO:root:System Free Memory: 400.0
# INFO:root:Iteration number: 8000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7371035814285278
# INFO:root:Divergence L2: 1.9745357036590576
# INFO:root:Vorticity L2: 1.9771251678466797
# INFO:root:Content L2: 0.6640905737876892
# INFO:root:Generator loss: -0.6639409065246582
# INFO:root:
# Epoch 29
# INFO:root:Gradient Penalty: 34.94065856933594
# INFO:root:Wasserstein Distance Estimate: 73.83595275878906
# INFO:root:System Free Memory: 373.0
# INFO:root:Iteration number: 8250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6610102653503418
# INFO:root:Divergence L2: 1.9784810543060303
# INFO:root:Vorticity L2: 1.9901732206344604
# INFO:root:Content L2: 0.715000331401825
# INFO:root:Generator loss: 1.23240327835083
# INFO:root:
# Epoch 30
# INFO:root:Gradient Penalty: 18.75492286682129
# INFO:root:Wasserstein Distance Estimate: 86.8442153930664
# INFO:root:System Free Memory: 396.0
# INFO:root:Iteration number: 8500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7659825086593628
# INFO:root:Divergence L2: 1.9753199815750122
# INFO:root:Vorticity L2: 1.9815391302108765
# INFO:root:Content L2: 0.7101426124572754
# INFO:root:Generator loss: 2.70660400390625
# INFO:root:
# Epoch 31
# INFO:root:Gradient Penalty: 51.112388610839844
# INFO:root:Wasserstein Distance Estimate: 146.18966674804688
# INFO:root:System Free Memory: 407.0
# INFO:root:Iteration number: 8750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6624653339385986
# INFO:root:Divergence L2: 1.9712055921554565
# INFO:root:Vorticity L2: 1.9773257970809937
# INFO:root:Content L2: 0.6520147323608398
# INFO:root:Generator loss: 0.438775897026062
# INFO:root:Gradient Penalty: 30.971439361572266
# INFO:root:Wasserstein Distance Estimate: 80.09037780761719
# INFO:root:System Free Memory: 397.0
# INFO:root:Iteration number: 9000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7784063816070557
# INFO:root:Divergence L2: 1.9674911499023438
# INFO:root:Vorticity L2: 1.9672904014587402
# INFO:root:Content L2: 0.592351496219635
# INFO:root:Generator loss: 1.0836650133132935
# INFO:root:
# Epoch 32
# INFO:root:Gradient Penalty: 34.621551513671875
# INFO:root:Wasserstein Distance Estimate: 107.46115112304688
# INFO:root:System Free Memory: 406.0
# INFO:root:Iteration number: 9250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6430208683013916
# INFO:root:Divergence L2: 1.9661084413528442
# INFO:root:Vorticity L2: 1.973592758178711
# INFO:root:Content L2: 0.6550815105438232
# INFO:root:Generator loss: -0.3793611526489258
# INFO:root:
# Epoch 33
# INFO:root:Gradient Penalty: 37.652374267578125
# INFO:root:Wasserstein Distance Estimate: 90.71356201171875
# INFO:root:System Free Memory: 386.0
# INFO:root:Iteration number: 9500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7469743490219116
# INFO:root:Divergence L2: 1.9595930576324463
# INFO:root:Vorticity L2: 1.9720757007598877
# INFO:root:Content L2: 0.7099231481552124
# INFO:root:Generator loss: -0.1595827341079712
# INFO:root:
# Epoch 34
# INFO:root:Gradient Penalty: 29.743026733398438
# INFO:root:Wasserstein Distance Estimate: 104.12709045410156
# INFO:root:System Free Memory: 447.0
# INFO:root:Iteration number: 9750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7167549133300781
# INFO:root:Divergence L2: 1.9668710231781006
# INFO:root:Vorticity L2: 1.9708833694458008
# INFO:root:Content L2: 0.5959147810935974
# INFO:root:Generator loss: 0.6069832444190979
# INFO:root:
# Epoch 35
# INFO:root:Gradient Penalty: 31.347835540771484
# INFO:root:Wasserstein Distance Estimate: 117.41850280761719
# INFO:root:System Free Memory: 425.0
# INFO:root:Iteration number: 10000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7682137489318848
# INFO:root:Divergence L2: 1.9683594703674316
# INFO:root:Vorticity L2: 1.9689087867736816
# INFO:root:Content L2: 0.6566283106803894
# INFO:root:Generator loss: 0.4102441072463989
# INFO:root:
# Epoch 36
# INFO:root:Gradient Penalty: 35.98747253417969
# INFO:root:Wasserstein Distance Estimate: 115.8292236328125
# INFO:root:System Free Memory: 441.0
# INFO:root:Iteration number: 10250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5949065685272217
# INFO:root:Divergence L2: 1.9615209102630615
# INFO:root:Vorticity L2: 1.9628710746765137
# INFO:root:Content L2: 0.668006181716919
# INFO:root:Generator loss: -1.6190463304519653
# INFO:root:
# Epoch 37
# INFO:root:Gradient Penalty: 28.914417266845703
# INFO:root:Wasserstein Distance Estimate: 91.33311462402344
# INFO:root:System Free Memory: 507.0
# INFO:root:Iteration number: 10500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8268887996673584
# INFO:root:Divergence L2: 1.9680856466293335
# INFO:root:Vorticity L2: 1.970134973526001
# INFO:root:Content L2: 0.6498292684555054
# INFO:root:Generator loss: 2.8329572677612305
# INFO:root:
# Epoch 38
# INFO:root:Gradient Penalty: 28.77354621887207
# INFO:root:Wasserstein Distance Estimate: 91.98190307617188
# INFO:root:System Free Memory: 489.0
# INFO:root:Iteration number: 10750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6475884914398193
# INFO:root:Divergence L2: 1.968877911567688
# INFO:root:Vorticity L2: 1.9754080772399902
# INFO:root:Content L2: 0.6758773326873779
# INFO:root:Generator loss: 3.2278313636779785
# INFO:root:
# Epoch 39
# INFO:root:Gradient Penalty: 29.673595428466797
# INFO:root:Wasserstein Distance Estimate: 74.99240112304688
# INFO:root:System Free Memory: 450.0
# INFO:root:Iteration number: 11000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7616500854492188
# INFO:root:Divergence L2: 1.9764517545700073
# INFO:root:Vorticity L2: 1.9785444736480713
# INFO:root:Content L2: 0.6648601293563843
# INFO:root:Generator loss: 1.3843050003051758
# INFO:root:Gradient Penalty: 26.975597381591797
# INFO:root:Wasserstein Distance Estimate: 98.12579345703125
# INFO:root:System Free Memory: 441.0
# INFO:root:Iteration number: 11250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.691435694694519
# INFO:root:Divergence L2: 1.9674094915390015
# INFO:root:Vorticity L2: 1.966338872909546
# INFO:root:Content L2: 0.6887472867965698
# INFO:root:Generator loss: 1.052577257156372
# INFO:root:
# Epoch 40
# INFO:root:Gradient Penalty: 28.68680763244629
# INFO:root:Wasserstein Distance Estimate: 115.58375549316406
# INFO:root:System Free Memory: 425.0
# INFO:root:Iteration number: 11500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6947550773620605
# INFO:root:Divergence L2: 1.9722050428390503
# INFO:root:Vorticity L2: 1.9761223793029785
# INFO:root:Content L2: 0.647382378578186
# INFO:root:Generator loss: -0.14000248908996582
# INFO:root:
# Epoch 41
# INFO:root:Gradient Penalty: 21.50385856628418
# INFO:root:Wasserstein Distance Estimate: 91.17922973632812
# INFO:root:System Free Memory: 413.0
# INFO:root:Iteration number: 11750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7904927730560303
# INFO:root:Divergence L2: 1.9693790674209595
# INFO:root:Vorticity L2: 1.9709293842315674
# INFO:root:Content L2: 0.6900536417961121
# INFO:root:Generator loss: 1.3329544067382812
# INFO:root:
# Epoch 42
# INFO:root:Gradient Penalty: 22.46138572692871
# INFO:root:Wasserstein Distance Estimate: 80.59912109375
# INFO:root:System Free Memory: 411.0
# INFO:root:Iteration number: 12000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7998555898666382
# INFO:root:Divergence L2: 1.9736666679382324
# INFO:root:Vorticity L2: 1.9862537384033203
# INFO:root:Content L2: 0.6871868968009949
# INFO:root:Generator loss: 0.6658449769020081
# INFO:root:
# Epoch 43
# INFO:root:Gradient Penalty: 26.06308364868164
# INFO:root:Wasserstein Distance Estimate: 81.35032653808594
# INFO:root:System Free Memory: 390.0
# INFO:root:Iteration number: 12250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6805866956710815
# INFO:root:Divergence L2: 1.966122031211853
# INFO:root:Vorticity L2: 1.959755539894104
# INFO:root:Content L2: 0.6027421355247498
# INFO:root:Generator loss: 0.7798600792884827
# INFO:root:
# Epoch 44
# INFO:root:Gradient Penalty: 36.855655670166016
# INFO:root:Wasserstein Distance Estimate: 107.80500793457031
# INFO:root:System Free Memory: 415.0
# INFO:root:Iteration number: 12500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6397666931152344
# INFO:root:Divergence L2: 1.9558802843093872
# INFO:root:Vorticity L2: 1.9511079788208008
# INFO:root:Content L2: 0.6161803603172302
# INFO:root:Generator loss: 2.001229763031006
# INFO:root:
# Epoch 45
# INFO:root:Gradient Penalty: 14.031478881835938
# INFO:root:Wasserstein Distance Estimate: 62.47906494140625
# INFO:root:System Free Memory: 393.0
# INFO:root:Iteration number: 12750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5614265203475952
# INFO:root:Divergence L2: 1.960988163948059
# INFO:root:Vorticity L2: 1.9540988206863403
# INFO:root:Content L2: 0.6101391911506653
# INFO:root:Generator loss: 0.4827629327774048
# INFO:root:
# Epoch 46
# INFO:root:Gradient Penalty: 29.851608276367188
# INFO:root:Wasserstein Distance Estimate: 117.12789916992188
# INFO:root:System Free Memory: 364.0
# INFO:root:Iteration number: 13000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.634174108505249
# INFO:root:Divergence L2: 1.9700219631195068
# INFO:root:Vorticity L2: 1.9652705192565918
# INFO:root:Content L2: 0.688034176826477
# INFO:root:Generator loss: 0.7930779457092285
# INFO:root:Gradient Penalty: 34.90785598754883
# INFO:root:Wasserstein Distance Estimate: 55.953277587890625
# INFO:root:System Free Memory: 400.0
# INFO:root:Iteration number: 13250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4844841957092285
# INFO:root:Divergence L2: 1.9564915895462036
# INFO:root:Vorticity L2: 1.9451344013214111
# INFO:root:Content L2: 0.6480838656425476
# INFO:root:Generator loss: -1.0420951843261719
# INFO:root:
# Epoch 47
# INFO:root:Gradient Penalty: 25.67715072631836
# INFO:root:Wasserstein Distance Estimate: 67.36575317382812
# INFO:root:System Free Memory: 407.0
# INFO:root:Iteration number: 13500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.618526577949524
# INFO:root:Divergence L2: 1.9627139568328857
# INFO:root:Vorticity L2: 1.9723836183547974
# INFO:root:Content L2: 0.6169911623001099
# INFO:root:Generator loss: -0.10476398468017578
# INFO:root:
# Epoch 48
# INFO:root:Gradient Penalty: 43.4466552734375
# INFO:root:Wasserstein Distance Estimate: 103.28630828857422
# INFO:root:System Free Memory: 402.0
# INFO:root:Iteration number: 13750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.404551386833191
# INFO:root:Divergence L2: 1.9486072063446045
# INFO:root:Vorticity L2: 1.9469720125198364
# INFO:root:Content L2: 0.5778433084487915
# INFO:root:Generator loss: 0.24819934368133545
# INFO:root:
# Epoch 49
# INFO:root:Gradient Penalty: 23.631879806518555
# INFO:root:Wasserstein Distance Estimate: 101.69920349121094
# INFO:root:System Free Memory: 464.0
# INFO:root:Iteration number: 14000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6117494106292725
# INFO:root:Divergence L2: 1.9593100547790527
# INFO:root:Vorticity L2: 1.9551278352737427
# INFO:root:Content L2: 0.6317012310028076
# INFO:root:Generator loss: 2.0707931518554688
# INFO:root:
# Epoch 50
# INFO:root:Gradient Penalty: 28.73590660095215
# INFO:root:Wasserstein Distance Estimate: 111.619873046875
# INFO:root:System Free Memory: 441.0
# INFO:root:Iteration number: 14250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5467883348464966
# INFO:root:Divergence L2: 1.9558085203170776
# INFO:root:Vorticity L2: 1.9620038270950317
# INFO:root:Content L2: 0.6888257265090942
# INFO:root:Generator loss: 1.1552284955978394
# INFO:root:
# Epoch 51
# INFO:root:Gradient Penalty: 14.823911666870117
# INFO:root:Wasserstein Distance Estimate: 83.86480712890625
# INFO:root:System Free Memory: 999.0
# INFO:root:Iteration number: 14500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6699743270874023
# INFO:root:Divergence L2: 1.9623533487319946
# INFO:root:Vorticity L2: 1.961649775505066
# INFO:root:Content L2: 0.5885643362998962
# INFO:root:Generator loss: -1.1793729066848755
# INFO:root:
# Epoch 52
# INFO:root:Gradient Penalty: 23.472599029541016
# INFO:root:Wasserstein Distance Estimate: 81.08833312988281
# INFO:root:System Free Memory: 953.0
# INFO:root:Iteration number: 14750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.484605073928833
# INFO:root:Divergence L2: 1.9628856182098389
# INFO:root:Vorticity L2: 1.9665690660476685
# INFO:root:Content L2: 0.6865881681442261
# INFO:root:Generator loss: -0.4572577476501465
# INFO:root:
# Epoch 53
# INFO:root:Gradient Penalty: 30.516109466552734
# INFO:root:Wasserstein Distance Estimate: 97.6020736694336
# INFO:root:System Free Memory: 855.0
# INFO:root:Iteration number: 15000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6073452234268188
# INFO:root:Divergence L2: 1.9607830047607422
# INFO:root:Vorticity L2: 1.9564796686172485
# INFO:root:Content L2: 0.6042485237121582
# INFO:root:Generator loss: 0.8440645337104797
# INFO:root:
# Epoch 54
# INFO:root:Gradient Penalty: 28.091793060302734
# INFO:root:Wasserstein Distance Estimate: 112.87294006347656
# INFO:root:System Free Memory: 845.0
# INFO:root:Iteration number: 15250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6385585069656372
# INFO:root:Divergence L2: 1.9575001001358032
# INFO:root:Vorticity L2: 1.9516916275024414
# INFO:root:Content L2: 0.6631081104278564
# INFO:root:Generator loss: 0.7001730799674988
# INFO:root:Gradient Penalty: 28.49203872680664
# INFO:root:Wasserstein Distance Estimate: 92.92735290527344
# INFO:root:System Free Memory: 937.0
# INFO:root:Iteration number: 15500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.622568130493164
# INFO:root:Divergence L2: 1.973050832748413
# INFO:root:Vorticity L2: 1.970505952835083
# INFO:root:Content L2: 0.7062692642211914
# INFO:root:Generator loss: -0.3882972002029419
# INFO:root:
# Epoch 55
# INFO:root:Gradient Penalty: 31.254589080810547
# INFO:root:Wasserstein Distance Estimate: 100.67012023925781
# INFO:root:System Free Memory: 372.0
# INFO:root:Iteration number: 15750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.489076852798462
# INFO:root:Divergence L2: 1.967729926109314
# INFO:root:Vorticity L2: 1.961371660232544
# INFO:root:Content L2: 0.5853335857391357
# INFO:root:Generator loss: -0.7517874240875244
# INFO:root:
# Epoch 56
# INFO:root:Gradient Penalty: 37.28334426879883
# INFO:root:Wasserstein Distance Estimate: 110.29428100585938
# INFO:root:System Free Memory: 363.0
# INFO:root:Iteration number: 16000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5644094944000244
# INFO:root:Divergence L2: 1.9628602266311646
# INFO:root:Vorticity L2: 1.959194302558899
# INFO:root:Content L2: 0.632243275642395
# INFO:root:Generator loss: 1.3020756244659424
# INFO:root:
# Epoch 57
# INFO:root:Gradient Penalty: 21.304508209228516
# INFO:root:Wasserstein Distance Estimate: 82.14237976074219
# INFO:root:System Free Memory: 939.0
# INFO:root:Iteration number: 16250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.8794101476669312
# INFO:root:Divergence L2: 1.9678987264633179
# INFO:root:Vorticity L2: 1.9671411514282227
# INFO:root:Content L2: 0.6410802602767944
# INFO:root:Generator loss: 0.7296147346496582
# INFO:root:
# Epoch 58
# INFO:root:Gradient Penalty: 22.780515670776367
# INFO:root:Wasserstein Distance Estimate: 141.884765625
# INFO:root:System Free Memory: 872.0
# INFO:root:Iteration number: 16500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6448726654052734
# INFO:root:Divergence L2: 1.9816317558288574
# INFO:root:Vorticity L2: 1.9774421453475952
# INFO:root:Content L2: 0.7256252765655518
# INFO:root:Generator loss: 1.7300679683685303
# INFO:root:
# Epoch 59
# INFO:root:Gradient Penalty: 27.66288948059082
# INFO:root:Wasserstein Distance Estimate: 84.63119506835938
# INFO:root:System Free Memory: 831.0
# INFO:root:Iteration number: 16750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7566245794296265
# INFO:root:Divergence L2: 1.9790419340133667
# INFO:root:Vorticity L2: 1.979814887046814
# INFO:root:Content L2: 0.6894676089286804
# INFO:root:Generator loss: -0.3758816719055176
# INFO:root:
# Epoch 60
# INFO:root:Gradient Penalty: 19.97581672668457
# INFO:root:Wasserstein Distance Estimate: 67.60870361328125
# INFO:root:System Free Memory: 823.0
# INFO:root:Iteration number: 17000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5732157230377197
# INFO:root:Divergence L2: 1.966914176940918
# INFO:root:Vorticity L2: 1.9602863788604736
# INFO:root:Content L2: 0.6873446702957153
# INFO:root:Generator loss: -0.6536871194839478
# INFO:root:
# Epoch 61
# INFO:root:Gradient Penalty: 25.971752166748047
# INFO:root:Wasserstein Distance Estimate: 90.0909423828125
# INFO:root:System Free Memory: 788.0
# INFO:root:Iteration number: 17250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7568817138671875
# INFO:root:Divergence L2: 1.9795548915863037
# INFO:root:Vorticity L2: 1.9812369346618652
# INFO:root:Content L2: 0.7449035048484802
# INFO:root:Generator loss: -1.523921012878418
# INFO:root:
# Epoch 62
# INFO:root:Gradient Penalty: 41.99678039550781
# INFO:root:Wasserstein Distance Estimate: 124.10252380371094
# INFO:root:System Free Memory: 765.0
# INFO:root:Iteration number: 17500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.7761682271957397
# INFO:root:Divergence L2: 1.9750677347183228
# INFO:root:Vorticity L2: 1.9764223098754883
# INFO:root:Content L2: 0.6778392791748047
# INFO:root:Generator loss: 0.87044358253479
# INFO:root:Gradient Penalty: 13.710923194885254
# INFO:root:Wasserstein Distance Estimate: 73.51342010498047
# INFO:root:System Free Memory: 774.0
# INFO:root:Iteration number: 17750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5744107961654663
# INFO:root:Divergence L2: 1.9597406387329102
# INFO:root:Vorticity L2: 1.9506391286849976
# INFO:root:Content L2: 0.6848298907279968
# INFO:root:Generator loss: 2.180314540863037
# INFO:root:
# Epoch 63
# INFO:root:Gradient Penalty: 27.817869186401367
# INFO:root:Wasserstein Distance Estimate: 95.0499267578125
# INFO:root:System Free Memory: 743.0
# INFO:root:Iteration number: 18000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4382896423339844
# INFO:root:Divergence L2: 1.9599534273147583
# INFO:root:Vorticity L2: 1.9577429294586182
# INFO:root:Content L2: 0.7079219818115234
# INFO:root:Generator loss: 4.452392578125
# INFO:root:
# Epoch 64
# INFO:root:Gradient Penalty: 32.00566864013672
# INFO:root:Wasserstein Distance Estimate: 124.0292739868164
# INFO:root:System Free Memory: 715.0
# INFO:root:Iteration number: 18250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6858140230178833
# INFO:root:Divergence L2: 1.9577606916427612
# INFO:root:Vorticity L2: 1.9549031257629395
# INFO:root:Content L2: 0.6305534243583679
# INFO:root:Generator loss: 1.0237634181976318
# INFO:root:
# Epoch 65
# INFO:root:Gradient Penalty: 31.16460609436035
# INFO:root:Wasserstein Distance Estimate: 64.56570434570312
# INFO:root:System Free Memory: 714.0
# INFO:root:Iteration number: 18500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5373183488845825
# INFO:root:Divergence L2: 1.9581767320632935
# INFO:root:Vorticity L2: 1.9489823579788208
# INFO:root:Content L2: 0.5684065818786621
# INFO:root:Generator loss: 1.5099506378173828
# INFO:root:
# Epoch 66
# INFO:root:Gradient Penalty: 23.686120986938477
# INFO:root:Wasserstein Distance Estimate: 62.717552185058594
# INFO:root:System Free Memory: 716.0
# INFO:root:Iteration number: 18750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5972341299057007
# INFO:root:Divergence L2: 1.9688596725463867
# INFO:root:Vorticity L2: 1.9682443141937256
# INFO:root:Content L2: 0.6807047128677368
# INFO:root:Generator loss: 2.6700804233551025
# INFO:root:
# Epoch 67
# INFO:root:Gradient Penalty: 21.366172790527344
# INFO:root:Wasserstein Distance Estimate: 83.3849868774414
# INFO:root:System Free Memory: 684.0
# INFO:root:Iteration number: 19000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5348336696624756
# INFO:root:Divergence L2: 1.9515841007232666
# INFO:root:Vorticity L2: 1.9426323175430298
# INFO:root:Content L2: 0.5605640411376953
# INFO:root:Generator loss: 1.325096607208252
# INFO:root:
# Epoch 68
# INFO:root:Gradient Penalty: 22.280620574951172
# INFO:root:Wasserstein Distance Estimate: 69.84088134765625
# INFO:root:System Free Memory: 647.0
# INFO:root:Iteration number: 19250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6449124813079834
# INFO:root:Divergence L2: 1.953192114830017
# INFO:root:Vorticity L2: 1.9560532569885254
# INFO:root:Content L2: 0.6433817148208618
# INFO:root:Generator loss: 4.144350051879883
# INFO:root:
# Epoch 69
# INFO:root:Gradient Penalty: 25.461118698120117
# INFO:root:Wasserstein Distance Estimate: 16.719043731689453
# INFO:root:System Free Memory: 656.0
# INFO:root:Iteration number: 19500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5954861640930176
# INFO:root:Divergence L2: 1.968471646308899
# INFO:root:Vorticity L2: 1.9693371057510376
# INFO:root:Content L2: 0.6768231391906738
# INFO:root:Generator loss: 2.0115554332733154
# INFO:root:
# Epoch 70
# INFO:root:Gradient Penalty: 21.005735397338867
# INFO:root:Wasserstein Distance Estimate: 65.6067123413086
# INFO:root:System Free Memory: 634.0
# INFO:root:Iteration number: 19750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.408237099647522
# INFO:root:Divergence L2: 1.9414786100387573
# INFO:root:Vorticity L2: 1.9327274560928345
# INFO:root:Content L2: 0.5972883105278015
# INFO:root:Generator loss: 1.2853989601135254
# INFO:root:Gradient Penalty: 21.640262603759766
# INFO:root:Wasserstein Distance Estimate: 79.93649291992188
# INFO:root:System Free Memory: 567.0
# INFO:root:Iteration number: 20000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5649312734603882
# INFO:root:Divergence L2: 1.953466773033142
# INFO:root:Vorticity L2: 1.9543745517730713
# INFO:root:Content L2: 0.6445568203926086
# INFO:root:Generator loss: -0.02343285083770752
# INFO:root:
# Epoch 71
# INFO:root:Gradient Penalty: 25.51404571533203
# INFO:root:Wasserstein Distance Estimate: 101.67178344726562
# INFO:root:System Free Memory: 571.0
# INFO:root:Iteration number: 20250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.486584186553955
# INFO:root:Divergence L2: 1.9458401203155518
# INFO:root:Vorticity L2: 1.9496490955352783
# INFO:root:Content L2: 0.6416885256767273
# INFO:root:Generator loss: -2.8312864303588867
# INFO:root:
# Epoch 72
# INFO:root:Gradient Penalty: 19.60137367248535
# INFO:root:Wasserstein Distance Estimate: 63.61262512207031
# INFO:root:System Free Memory: 585.0
# INFO:root:Iteration number: 20500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6098382472991943
# INFO:root:Divergence L2: 1.9720468521118164
# INFO:root:Vorticity L2: 1.972692847251892
# INFO:root:Content L2: 0.7564172148704529
# INFO:root:Generator loss: 3.962893009185791
# INFO:root:
# Epoch 73
# INFO:root:Gradient Penalty: 29.02074432373047
# INFO:root:Wasserstein Distance Estimate: 88.19784545898438
# INFO:root:System Free Memory: 521.0
# INFO:root:Iteration number: 20750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5488578081130981
# INFO:root:Divergence L2: 1.9670822620391846
# INFO:root:Vorticity L2: 1.9674534797668457
# INFO:root:Content L2: 0.5854917764663696
# INFO:root:Generator loss: -1.385143756866455
# INFO:root:
# Epoch 74
# INFO:root:Gradient Penalty: 30.24893569946289
# INFO:root:Wasserstein Distance Estimate: 90.16366577148438
# INFO:root:System Free Memory: 506.0
# INFO:root:Iteration number: 21000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.598338007926941
# INFO:root:Divergence L2: 1.9684717655181885
# INFO:root:Vorticity L2: 1.966652274131775
# INFO:root:Content L2: 0.7190761566162109
# INFO:root:Generator loss: 1.6675593852996826
# INFO:root:
# Epoch 75
# INFO:root:Gradient Penalty: 18.527408599853516
# INFO:root:Wasserstein Distance Estimate: 66.10946655273438
# INFO:root:System Free Memory: 497.0
# INFO:root:Iteration number: 21250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5801407098770142
# INFO:root:Divergence L2: 1.9571200609207153
# INFO:root:Vorticity L2: 1.9616574048995972
# INFO:root:Content L2: 0.7010223865509033
# INFO:root:Generator loss: 0.6038917899131775
# INFO:root:
# Epoch 76
# INFO:root:Gradient Penalty: 17.324081420898438
# INFO:root:Wasserstein Distance Estimate: 77.090087890625
# INFO:root:System Free Memory: 491.0
# INFO:root:Iteration number: 21500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4797613620758057
# INFO:root:Divergence L2: 1.9524251222610474
# INFO:root:Vorticity L2: 1.9584951400756836
# INFO:root:Content L2: 0.6364374160766602
# INFO:root:Generator loss: 0.023455500602722168
# INFO:root:
# Epoch 77
# INFO:root:Gradient Penalty: 20.61824607849121
# INFO:root:Wasserstein Distance Estimate: 52.82769012451172
# INFO:root:System Free Memory: 673.0
# INFO:root:Iteration number: 21750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.596900463104248
# INFO:root:Divergence L2: 1.9521788358688354
# INFO:root:Vorticity L2: 1.9521923065185547
# INFO:root:Content L2: 0.6076678037643433
# INFO:root:Generator loss: 1.368595004081726
# INFO:root:
# Epoch 78
# INFO:root:Gradient Penalty: 35.556312561035156
# INFO:root:Wasserstein Distance Estimate: 87.42219543457031
# INFO:root:System Free Memory: 700.0
# INFO:root:Iteration number: 22000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4346250295639038
# INFO:root:Divergence L2: 1.9508140087127686
# INFO:root:Vorticity L2: 1.9396116733551025
# INFO:root:Content L2: 0.6122256517410278
# INFO:root:Generator loss: 1.3768725395202637
# INFO:root:Gradient Penalty: 16.496013641357422
# INFO:root:Wasserstein Distance Estimate: 58.14996337890625
# INFO:root:System Free Memory: 654.0
# INFO:root:Iteration number: 22250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6200098991394043
# INFO:root:Divergence L2: 1.9456835985183716
# INFO:root:Vorticity L2: 1.94577956199646
# INFO:root:Content L2: 0.6135851144790649
# INFO:root:Generator loss: 0.05663275718688965
# INFO:root:
# Epoch 79
# INFO:root:Gradient Penalty: 19.327116012573242
# INFO:root:Wasserstein Distance Estimate: 69.26028442382812
# INFO:root:System Free Memory: 827.0
# INFO:root:Iteration number: 22500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4897431135177612
# INFO:root:Divergence L2: 1.9395087957382202
# INFO:root:Vorticity L2: 1.9415761232376099
# INFO:root:Content L2: 0.5969498157501221
# INFO:root:Generator loss: -0.9789459705352783
# INFO:root:
# Epoch 80
# INFO:root:Gradient Penalty: 23.055606842041016
# INFO:root:Wasserstein Distance Estimate: 73.87007141113281
# INFO:root:System Free Memory: 802.0
# INFO:root:Iteration number: 22750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4593843221664429
# INFO:root:Divergence L2: 1.9335711002349854
# INFO:root:Vorticity L2: 1.9325356483459473
# INFO:root:Content L2: 0.5819830298423767
# INFO:root:Generator loss: 0.06582534313201904
# INFO:root:
# Epoch 81
# INFO:root:Gradient Penalty: 34.382347106933594
# INFO:root:Wasserstein Distance Estimate: 96.72348022460938
# INFO:root:System Free Memory: 773.0
# INFO:root:Iteration number: 23000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6220132112503052
# INFO:root:Divergence L2: 1.9376462697982788
# INFO:root:Vorticity L2: 1.9302120208740234
# INFO:root:Content L2: 0.5779871344566345
# INFO:root:Generator loss: -0.21684443950653076
# INFO:root:
# Epoch 82
# INFO:root:Gradient Penalty: 30.575895309448242
# INFO:root:Wasserstein Distance Estimate: 54.541290283203125
# INFO:root:System Free Memory: 686.0
# INFO:root:Iteration number: 23250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.596457839012146
# INFO:root:Divergence L2: 1.9539589881896973
# INFO:root:Vorticity L2: 1.949127435684204
# INFO:root:Content L2: 0.6312307119369507
# INFO:root:Generator loss: -0.5509880781173706
# INFO:root:
# Epoch 83
# INFO:root:Gradient Penalty: 19.751558303833008
# INFO:root:Wasserstein Distance Estimate: 62.90133285522461
# INFO:root:System Free Memory: 679.0
# INFO:root:Iteration number: 23500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6170694828033447
# INFO:root:Divergence L2: 1.956251859664917
# INFO:root:Vorticity L2: 1.95872163772583
# INFO:root:Content L2: 0.6208356618881226
# INFO:root:Generator loss: 1.2932120561599731
# INFO:root:
# Epoch 84
# INFO:root:Gradient Penalty: 11.217331886291504
# INFO:root:Wasserstein Distance Estimate: 40.108299255371094
# INFO:root:System Free Memory: 639.0
# INFO:root:Iteration number: 23750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5297188758850098
# INFO:root:Divergence L2: 1.953105092048645
# INFO:root:Vorticity L2: 1.9415371417999268
# INFO:root:Content L2: 0.6094580888748169
# INFO:root:Generator loss: 2.4773988723754883
# INFO:root:
# Epoch 85
# INFO:root:Gradient Penalty: 31.020980834960938
# INFO:root:Wasserstein Distance Estimate: 48.3826904296875
# INFO:root:System Free Memory: 640.0
# INFO:root:Iteration number: 24000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.52615487575531
# INFO:root:Divergence L2: 1.9636434316635132
# INFO:root:Vorticity L2: 1.9632924795150757
# INFO:root:Content L2: 0.5868490934371948
# INFO:root:Generator loss: -1.387040138244629
# INFO:root:Gradient Penalty: 16.97664451599121
# INFO:root:Wasserstein Distance Estimate: 77.11724090576172
# INFO:root:System Free Memory: 634.0
# INFO:root:Iteration number: 24250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.595186471939087
# INFO:root:Divergence L2: 1.9763792753219604
# INFO:root:Vorticity L2: 1.9710062742233276
# INFO:root:Content L2: 0.7427352666854858
# INFO:root:Generator loss: 3.5283989906311035
# INFO:root:
# Epoch 86
# INFO:root:Gradient Penalty: 37.841888427734375
# INFO:root:Wasserstein Distance Estimate: 112.76614379882812
# INFO:root:System Free Memory: 525.0
# INFO:root:Iteration number: 24500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4930163621902466
# INFO:root:Divergence L2: 1.9475631713867188
# INFO:root:Vorticity L2: 1.9383883476257324
# INFO:root:Content L2: 0.6232024431228638
# INFO:root:Generator loss: -1.417695164680481
# INFO:root:
# Epoch 87
# INFO:root:Gradient Penalty: 16.045339584350586
# INFO:root:Wasserstein Distance Estimate: 61.887351989746094
# INFO:root:System Free Memory: 538.0
# INFO:root:Iteration number: 24750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.530566930770874
# INFO:root:Divergence L2: 1.9451498985290527
# INFO:root:Vorticity L2: 1.9380401372909546
# INFO:root:Content L2: 0.612671434879303
# INFO:root:Generator loss: 2.4596073627471924
# INFO:root:
# Epoch 88
# INFO:root:Gradient Penalty: 18.445913314819336
# INFO:root:Wasserstein Distance Estimate: 78.71029663085938
# INFO:root:System Free Memory: 511.0
# INFO:root:Iteration number: 25000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.588705062866211
# INFO:root:Divergence L2: 1.9449979066848755
# INFO:root:Vorticity L2: 1.9498810768127441
# INFO:root:Content L2: 0.6349887251853943
# INFO:root:Generator loss: -0.9846454858779907
# INFO:root:
# Epoch 89
# INFO:root:Gradient Penalty: 18.581911087036133
# INFO:root:Wasserstein Distance Estimate: 64.58053588867188
# INFO:root:System Free Memory: 491.0
# INFO:root:Iteration number: 25250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5492641925811768
# INFO:root:Divergence L2: 1.9546054601669312
# INFO:root:Vorticity L2: 1.957331895828247
# INFO:root:Content L2: 0.6656782031059265
# INFO:root:Generator loss: 1.8530458211898804
# INFO:root:
# Epoch 90
# INFO:root:Gradient Penalty: 17.877748489379883
# INFO:root:Wasserstein Distance Estimate: 68.59150695800781
# INFO:root:System Free Memory: 488.0
# INFO:root:Iteration number: 25500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6071232557296753
# INFO:root:Divergence L2: 1.93699049949646
# INFO:root:Vorticity L2: 1.9337290525436401
# INFO:root:Content L2: 0.6231920123100281
# INFO:root:Generator loss: 2.633742332458496
# INFO:root:
# Epoch 91
# INFO:root:Gradient Penalty: 14.811972618103027
# INFO:root:Wasserstein Distance Estimate: 60.87559127807617
# INFO:root:System Free Memory: 391.0
# INFO:root:Iteration number: 25750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5729986429214478
# INFO:root:Divergence L2: 1.9425292015075684
# INFO:root:Vorticity L2: 1.9428658485412598
# INFO:root:Content L2: 0.6355177760124207
# INFO:root:Generator loss: 1.0579895973205566
# INFO:root:
# Epoch 92
# INFO:root:Gradient Penalty: 22.819839477539062
# INFO:root:Wasserstein Distance Estimate: 75.73260498046875
# INFO:root:System Free Memory: 382.0
# INFO:root:Iteration number: 26000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5590918064117432
# INFO:root:Divergence L2: 1.9346786737442017
# INFO:root:Vorticity L2: 1.9250324964523315
# INFO:root:Content L2: 0.5577264428138733
# INFO:root:Generator loss: -1.2384700775146484
# INFO:root:
# Epoch 93
# INFO:root:Gradient Penalty: 16.31608772277832
# INFO:root:Wasserstein Distance Estimate: 67.02709197998047
# INFO:root:System Free Memory: 583.0
# INFO:root:Iteration number: 26250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5364919900894165
# INFO:root:Divergence L2: 1.9302211999893188
# INFO:root:Vorticity L2: 1.9330731630325317
# INFO:root:Content L2: 0.6585360169410706
# INFO:root:Generator loss: 0.9907007217407227
# INFO:root:Gradient Penalty: 30.035860061645508
# INFO:root:Wasserstein Distance Estimate: 78.68276977539062
# INFO:root:System Free Memory: 522.0
# INFO:root:Iteration number: 26500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.545678734779358
# INFO:root:Divergence L2: 1.954970359802246
# INFO:root:Vorticity L2: 1.9428300857543945
# INFO:root:Content L2: 0.6615290641784668
# INFO:root:Generator loss: 4.643332004547119
# INFO:root:
# Epoch 94
# INFO:root:Gradient Penalty: 20.68446922302246
# INFO:root:Wasserstein Distance Estimate: 64.92474365234375
# INFO:root:System Free Memory: 528.0
# INFO:root:Iteration number: 26750
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6103901863098145
# INFO:root:Divergence L2: 1.9384398460388184
# INFO:root:Vorticity L2: 1.9412903785705566
# INFO:root:Content L2: 0.5867566466331482
# INFO:root:Generator loss: -1.9546210765838623
# INFO:root:
# Epoch 95
# INFO:root:Gradient Penalty: 22.389007568359375
# INFO:root:Wasserstein Distance Estimate: 80.60202026367188
# INFO:root:System Free Memory: 480.0
# INFO:root:Iteration number: 27000
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.6157277822494507
# INFO:root:Divergence L2: 1.9499346017837524
# INFO:root:Vorticity L2: 1.9490604400634766
# INFO:root:Content L2: 0.6762241721153259
# INFO:root:Generator loss: 3.6664559841156006
# INFO:root:
# Epoch 96
# INFO:root:Gradient Penalty: 18.985536575317383
# INFO:root:Wasserstein Distance Estimate: 68.75457763671875
# INFO:root:System Free Memory: 471.0
# INFO:root:Iteration number: 27250
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.4314348697662354
# INFO:root:Divergence L2: 1.9423960447311401
# INFO:root:Vorticity L2: 1.9379301071166992
# INFO:root:Content L2: 0.5718149542808533
# INFO:root:Generator loss: -0.9877402782440186
# INFO:root:
# Epoch 97
# INFO:root:Gradient Penalty: 17.28812026977539
# INFO:root:Wasserstein Distance Estimate: 73.02713012695312
# INFO:root:System Free Memory: 432.0
# INFO:root:Iteration number: 27500
# INFO:root:GPU Memory: 874834432
# INFO:root:EOF Coefficient L2: 1.5838122367858887
# INFO:root:Divergence L2: 1.961255431175232
# INFO:root:Vorticity L2: 1.957023024559021
# INFO:root:Content L2: 0.6989431381225586
# INFO:root:Generator loss: 3.7583117485046387
# INFO:root:
# Epoch 98

# %%
torch.cuda.empty_cache()

# %%
import mlflow
mlflow.start_run?

# %%
import mlflow
logged_model = 'file:///home/nannau/msc/DoWnGAN/mlruns/1/804c42df4312453d8506e8b16fd46bc7/artifacts/Generator'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: Generator
#   flavor: mlflow.pytorch
#   run_id: 804c42df4312453d8506e8b16fd46bc7

# %%
loaded_model = mlflow.pytorch.load_model(logged_model).to(device)
loaded_model(fixed["coarse"].to(device))
# Out:
# tensor([[[[-3.5388e-01, -4.8582e-01, -5.9356e-01,  ..., -1.3861e+00,
#            -1.1772e+00, -8.4754e-01],
#           [-3.7704e-01, -4.5386e-01, -5.6603e-01,  ..., -1.4965e+00,
#            -1.2917e+00, -1.0280e+00],
#           [-4.3806e-01, -5.8303e-01, -6.0858e-01,  ..., -1.7329e+00,
#            -1.4795e+00, -1.0681e+00],
#           ...,
#           [ 1.2753e-01,  1.1490e-01,  1.6337e-01,  ..., -2.9095e-02,
#             7.5807e-03,  2.4980e-02],
#           [ 9.2736e-02,  9.5301e-02,  1.3478e-01,  ..., -4.0386e-03,
#             2.4528e-02,  4.6090e-02],
#           [ 9.7056e-02,  9.9583e-02,  1.2274e-01,  ...,  5.7548e-02,
#             3.5298e-02,  3.6050e-02]],
#
#          [[ 3.6496e-01,  4.0098e-01,  4.1650e-01,  ...,  3.4476e-03,
#             5.0537e-02, -1.2567e-01],
#           [ 4.7568e-01,  5.3864e-01,  6.4374e-01,  ...,  1.2802e-02,
#            -1.5882e-03, -7.8880e-03],
#           [ 5.9953e-01,  7.1660e-01,  6.8409e-01,  ...,  8.9383e-02,
#             1.1287e-01,  8.7134e-02],
#           ...,
#           [ 4.6119e-02,  7.9566e-02,  9.2078e-02,  ...,  7.9368e-02,
#             9.1867e-02,  5.7008e-02],
#           [ 2.3212e-02,  1.6093e-02,  7.8913e-02,  ...,  1.1930e-01,
#             1.3696e-01,  1.0058e-01],
#           [ 1.0957e-02,  2.5906e-03,  2.5397e-02,  ...,  8.7181e-02,
#             1.3331e-01,  7.2135e-02]]],
#
#
#         [[[-7.0684e-02, -1.3365e-01, -9.8992e-02,  ..., -8.8339e-01,
#            -7.4860e-01, -5.2800e-01],
#           [-2.6671e-02, -5.8298e-02, -5.0782e-02,  ..., -9.5482e-01,
#            -8.0654e-01, -6.5553e-01],
#           [-7.5475e-02, -1.4832e-01, -1.3249e-01,  ..., -1.1038e+00,
#            -9.1025e-01, -6.5218e-01],
#           ...,
#           [ 6.3937e-01,  7.1746e-01,  9.4744e-01,  ...,  6.1244e-01,
#             6.8211e-01,  5.2035e-01],
#           [ 5.5031e-01,  6.5506e-01,  7.6817e-01,  ...,  7.2229e-01,
#             6.2270e-01,  4.1476e-01],
#           [ 4.6927e-01,  5.2175e-01,  6.1810e-01,  ...,  6.9677e-01,
#             6.0764e-01,  4.5985e-01]],
#
#          [[-2.6322e-01, -2.9019e-01, -4.4013e-01,  ..., -3.2777e-01,
#            -2.8311e-01, -2.6781e-01],
#           [-2.7783e-01, -3.7412e-01, -4.6178e-01,  ..., -4.9528e-01,
#            -4.0285e-01, -2.8461e-01],
#           [-3.3758e-01, -3.8246e-01, -5.9163e-01,  ..., -4.7414e-01,
#            -3.6277e-01, -2.9404e-01],
#           ...,
#           [-5.1781e-01, -6.1530e-01, -5.7773e-01,  ...,  2.2682e+00,
#             2.1496e+00,  1.6065e+00],
#           [-4.9077e-01, -5.6888e-01, -6.0191e-01,  ...,  2.2391e+00,
#             1.9399e+00,  1.5255e+00],
#           [-3.6059e-01, -4.4059e-01, -4.4076e-01,  ...,  1.8885e+00,
#             1.7629e+00,  1.3446e+00]]]], device='cuda:0',
#        grad_fn=<AddBackward0>)

# %%
import mlflow
runs = mlflow.search_runs(experiment_ids="1")
runs.head(10)
# Out:
#                              run_id experiment_id   status  \
# 0  6448b64a8d8a445288375be22ed1b270             1  RUNNING
# 1  be35a158b37f4b18b52e7da67f3ab7cf             1   FAILED
# 2  804c42df4312453d8506e8b16fd46bc7             1  RUNNING
#
#                                         artifact_uri  \
# 0  file:///home/nannau/msc/DoWnGAN/mlruns/1/6448b...
# 1  file:///home/nannau/msc/DoWnGAN/mlruns/1/be35a...
# 2  file:///home/nannau/msc/DoWnGAN/mlruns/1/804c4...
#
#                         start_time                         end_time  \
# 0 2021-05-26 21:22:45.426000+00:00                              NaT
# 1 2021-05-26 21:06:09.803000+00:00 2021-05-26 21:20:25.045000+00:00
# 2 2021-05-26 19:25:09.495000+00:00                              NaT
#
#    metrics.Wasserstein Distance Estimate  metrics.Divergence L2  \
# 0                                    NaN                    NaN
# 1                             168.159500               1.982799
# 2                              90.006012               1.965402
#
#    metrics.GPU Memory  metrics.EOF Coefficient L2  ...  params.vort_weight  \
# 0                 NaN                         NaN  ...              0.2475
# 1         261215744.0                    2.036446  ...              0.2475
# 2         261215744.0                    1.771552  ...              0.2475
#
#    params.critic_iterations  tags.mlflow.source.name  \
# 0                         5          process_data.py
# 1                         5          process_data.py
# 2                         5          process_data.py
#
#               tags.mlflow.source.git.commit  tags.mlflow.source.type  \
# 0  82040d9938170a941bf93c4379283b664f18279e                    LOCAL
# 1  82040d9938170a941bf93c4379283b664f18279e                    LOCAL
# 2  82040d9938170a941bf93c4379283b664f18279e                    LOCAL
#
#    tags.mlflow.user     tags.6448b64a8d8a445288375be22ed1b270  \
# 0            nannau  {'description': 'equal weights on loss'}
# 1            nannau                                      None
# 2            nannau                                      None
#
#                        tags.mlflow.log-model.history  \
# 0                                               None
# 1  [{"run_id": "be35a158b37f4b18b52e7da67f3ab7cf"...
# 2  [{"run_id": "804c42df4312453d8506e8b16fd46bc7"...
#
#       tags.be35a158b37f4b18b52e7da67f3ab7cf  \
# 0                                      None
# 1  {'description': 'equal weights on loss'}
# 2                                      None
#
#       tags.804c42df4312453d8506e8b16fd46bc7
# 0                                      None
# 1                                      None
# 2  {'description': 'equal weights on loss'}
#
# [3 rows x 33 columns]
